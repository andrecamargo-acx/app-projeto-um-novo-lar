# %%
import os, jsonfrom pathlib import PathCONFIG_PATH = Path('mysql_config.json')class Config:    SECRET_KEY = os.getenv('SECRET_KEY', 'changeme')    # Token fixo para MVP    GEMINI_API_KEY = 'AIzaSyBzGnwcfhIQT_ix-uD756HuTkEj58FmXKc'    # Modelo atualizado 2.5 flash    GEMINI_MODEL = 'gemini-2.5-flash'    @staticmethod    def load_mysql_config():        host = os.getenv('DB_HOST')        if host:            return {                "host": host,                "port": int(os.getenv("DB_PORT", "3306")),                "user": os.getenv("DB_USER"),                "password": os.getenv("DB_PASSWORD"),                "database": os.getenv("DB_NAME")            }        if not CONFIG_PATH.exists():            raise FileNotFoundError("mysql_config.json não encontrado.")        return json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
