# %%
from flask import Flaskfrom config import Config# Aqui você registraria seus blueprints depois# ex:# from web.auth_routes import bp_auth# from web.people_routes import bp_people# from web.dashboard_routes import bp_dashdef create_app():    app = Flask(__name__)    app.config["SECRET_KEY"] = Config.SECRET_KEY    # app.register_blueprint(bp_auth)    # app.register_blueprint(bp_people)    # app.register_blueprint(bp_dash)    @app.route("/")    def index():        return "Um Novo Lar - App Modularizado"    return appif __name__ == "__main__":    app = create_app()    app.run(debug=True)
